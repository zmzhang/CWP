# %%
import pandas as pd
mol_descriptor_data = pd.read_csv('molecular_descriptors.csv')
mol_descriptor_data
# Out:
#      Molecule_Name                                             SMILES  \
# 0          Aspirin                           CC(=O)OC1=CC=CC=C1C(=O)O
# 1         Caffeine                       CN1C=NC2=C1C(=O)N(C(=O)N2C)C
# 2        Ibuprofen                      CC(C)CC1=CC=C(C=C1)C(C)C(=O)O
# 3    Acetaminophen                              CC(=O)NC1=CC=C(C=C1)O
# 4       Penicillin  CC1([C@@H](N2[C@H](S1)[C@@H](C2=O)NC(=O)CC3=CC...
# 5         Morphine  CN1CC[C@]23C4=C5C=CC(=C4CC[C@H]2[C@H]1C[C@H]3O...
# 6         Dopamine                               NCCC1=CC(=C(C=C1)O)O
# 7        Serotonin                            NCCC1=CNC2=C1C=CC(=C2)O
# 8          Glucose             OC[C@H]1OC(O)[C@H](O)[C@@H](O)[C@@H]1O
# 9      Cholesterol  CC(C)CCC[C@@H](C)[C@H]1CC[C@H]2[C@@H]3CC=C4C[C...
# 10    Testosterone  C[C@]12CC[C@H]3[C@H]([C@@H]1CC[C@@H]2O)CCC4=CC...
# 11       Estradiol  C[C@]12CC[C@H]3[C@H]([C@@H]1CC[C@@H]2O)CCC4=C3...
# ...
