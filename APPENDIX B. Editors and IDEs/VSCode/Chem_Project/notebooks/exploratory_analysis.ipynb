# %% [markdown]
# # Imports

# %%
from rdkit import Chem
from rdkit.Chem import Draw
from rdkit.Chem.Draw import IPythonConsole
IPythonConsole.ipython_useSVG = True # Use high-quality SVG rendering

# %% [markdown]
# # Create and display molecule

# %%
ibuprofen_smiles = "CC(C)CC1=CC=C(C=C1)C(C)C(=O)O"
mol = Chem.MolFromSmiles(ibuprofen_smiles)
mol # Display the molecule directly in the output
